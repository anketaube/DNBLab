# %%
# IMPORTE
import numpy
import pandas as pd
import re
import os
from pprint import pprint
import spacy
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

stoplist = pd.read_csv('stopwords-de.txt', header=None)[0].values.tolist()

# %%
# LOAD DATA

name = 'dnbf_visionen23'
filename = name+'.txt'
dfimport = pd.read_csv(filename, sep="|")

commentframe = dfimport['text']
data = commentframe.values.tolist()
print(len(data))
print(data[1])
# Out:
# 117
# Bibliotheken der Zukunft sollten "alles" anbieten. Es wird immer Menschen geben, die Bücher in Papier in der Hand halten möchten. E-Book-Reader sind platzsparend und eine gute Ergänzung. Interaktive Medien könnten interessant sein. Weiterhin auch gerne CDs, DVDs, Hörbücher. Schöne Lesebereiche können locken.

# %%
# Load spaCy model

nlp = spacy.load('de_core_news_sm', disable=['parser', 'ner'])
# Assuming 'stoplist' contains your list of stopwords
stoplist = pd.read_csv('stopwords-de.txt', header=None)[0].values.tolist()

# Tokenize and lemmatize the comments, excluding stopwords
data_words_nostops = []

for comment in data:
    # Tokenize the comment using spaCy
    doc = nlp(comment)
    
    # Extract lemmatized words excluding stopwords
    processed_words = [token.lemma_ for token in doc if token.lemma_ not in stoplist]
    
    data_words_nostops.append(processed_words)

# %%
# Lemmatisierung
def lemmatization(texts, allowed_postags=['NOUN', 'PROPN', 'VERB', 'ADJ', 'ADV']):
  texts_out = []
  for sent in texts:
    doc = nlp(" ".join(sent))
    texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
  return texts_out


data_lemmatized = lemmatization(data_words_nostops, allowed_postags=['NOUN', 'PROPN', 'VERB', 'ADJ', 'ADV'])
#print('lemmata: ' + str(data_lemmatized[:9]))

# Lemmatisierte Daten erneut durch Stoplist schleifen
#data_final = [[word for word in doc if len(word) > 2 and word not in stoplist] for doc in data_lemmatized]

# %%
# Lemmatisierte Daten erneut durch Stoplist schleifen
data_final = [[word for word in doc if len(word) > 2 and word not in stoplist] for doc in data_lemmatized]
print(data_final[1])
# Out:
# ['Bibliothek', 'Zukunft', 'anbieten', 'Mensch', 'geben', 'Buch', 'Papier', 'Hand', 'halten', 'E-Book-Reader', 'platzsparend', 'Ergänzung', 'Interaktive', 'Medium', 'interessant', 'weiterhin', 'gerne', 'DVDs', 'Hörbücher', 'schön', 'Lesebereich', 'locken']

# %%
type(data_final)
# Out:
# list

# %%
# elbow method to approximate sufficiant number of topics

import matplotlib.pyplot as plt
from gensim.models import LdaModel
from gensim.corpora import Dictionary

# Assuming 'corpus' is your document-term matrix and 'id2word' is the mapping from word ids to words
# You may need to replace 'num_topics_range' with the range of values you want to explore

num_topics_range = range(2, 16)
perplexity_values = []
id2word = corpora.Dictionary(data_final)
corpus = [id2word.doc2bow(text) for text in data_final]

for num_topics in num_topics_range:
    lda_model = LdaModel(corpus=corpus, id2word=id2word, num_topics=num_topics, random_state=42) # CAUTION!
    perplexity = lda_model.log_perplexity(corpus)
    perplexity_values.append(perplexity)

# Plotting the results
plt.plot(num_topics_range, perplexity_values, marker='o')
plt.title('Perplexity vs. Number of Topics')
plt.xlabel('Number of Topics')
plt.ylabel('Perplexity')
plt.savefig('TopicNumElbow.svg')
plt.show()

# %%
# TRAINING

num_topics = 10 # Anzahl der Themen, nach denen die Daten gegliedert werden sollen, Zahl kann frei geändert werden
chunks = len(data)

#id2word = corpora.Dictionary(data_final)
#print('id2word: '+str(id2word))

#corpus = [id2word.doc2bow(text) for text in data_final]
#print('corpus: '+str(corpus))

lda_model = gensim.models.ldamodel.LdaModel(
   corpus=corpus, id2word=id2word, num_topics=num_topics, random_state=100,
   update_every=1, chunksize=chunks, passes=10, alpha='auto', per_word_topics=True
)

#pprint(lda_model.print_topics(num_topics=50))
pprint(lda_model.print_topics(num_topics))

doc_lda = lda_model[corpus]


print('\nPerplexity: ', lda_model.log_perplexity(corpus))
# Out:
# [(0,
#   '0.025*"jederzeit" + 0.025*"Zukunft" + 0.025*"Bibliothek" + '
#   '0.013*"Digitalisierung" + 0.013*"zugänglich" + 0.013*"technisch" + '
#   '0.013*"komplett" + 0.013*"frei" + 0.013*"nutzbar" + 0.013*"einfach"'),
#  (1,
#   '0.037*"Ort" + 0.037*"Bibliothek" + 0.019*"treffen" + 0.019*"untereinander" '
#   '+ 0.019*"Buch" + 0.010*"öffnen" + 0.010*"Abend" + 0.010*"luogon" + '
#   '0.010*"aperto" + 0.010*"incontro(?)/menutia"'),
#  (2,
#   '0.032*"Bibliothek" + 0.021*"Kreativität" + 0.021*"Relevanz" + '
#   '0.021*"bleiben" + 0.021*"Buch" + 0.011*"teilen" + 0.011*"alt" + '
#   '0.011*"Diversität" + 0.011*"Begegnung" + 0.011*"Nachhaltigkeit"'),
#  (3,
#   '0.049*"Ort" + 0.033*"Buch" + 0.025*"neu" + 0.025*"lernen" + '
#   '0.017*"aufbewahren" + 0.017*"geben" + 0.017*"deutsch" + 0.017*"treffen" + '
#   '0.017*"Bibliothek" + 0.009*"Hinsicht"'),
#  (4,
#   '0.032*"Ope" + 0.021*"Raum" + 0.021*"gemeinsam" + 0.021*"DNB" + '
#   '0.021*"Video" + 0.021*"library" + 0.011*"Nation" + 0.011*"Lindere" + '
#   '0.011*"wünschen" + 0.011*"neu"'),
#  (5,
#   '0.055*"Buch" + 0.048*"Bibliothek" + 0.041*"Mensch" + 0.028*"Zukunft" + '
#   '0.014*"öffentlich" + 0.007*"Papier" + 0.007*"bringen" + 0.007*"Medium" + '
#   '0.007*"weiterhin" + 0.007*"gerne"'),
#  (6,
#   '0.035*"DNB" + 0.018*"z.B." + 0.018*"Standort" + 0.018*"Bibliothek" + '
#   '0.018*"Vielfalt" + 0.009*"Buch" + 0.009*"Zentraler" + '
#   '0.009*"Dienstleistungs-)Funktion" + 0.009*"wissenschaftlich" + '
#   '0.009*"u.a."'),
#  (7,
#   '0.028*"Ort" + 0.028*"Buch" + 0.019*"Bibliothek" + 0.019*"The" + '
#   '0.019*"Book" + 0.019*"Papier" + 0.019*"schützen" + 0.019*"Raum" + '
#   '0.010*"Gelehrsamkeit" + 0.010*"schnell"'),
#  (8,
#   '0.064*"Bibliothek" + 0.019*"kostenlos" + 0.010*"lernen" + 0.010*"Buch" + '
#   '0.010*"vielfältig" + 0.010*"Zugänglichkeit" + 0.010*"lächeln" + '
#   '0.010*"Toll" + 0.010*"Fokus" + 0.010*"Metadat"'),
#  (9,
#   '0.034*"Buch" + 0.021*"Bibliothek" + 0.021*"alt" + 0.014*"Zukunft" + '
#   '0.014*"beamen" + 0.014*"Cloud" + 0.014*"Seite" + 0.014*"Hörbücher" + '
#   '0.007*"wünschen" + 0.007*"Zugang"')]
#
# Perplexity:  -6.799314772030886

# %%
# Define a mapping from topic numbers to labels
topic_labels = {
    0: "Digitalisierung Zugänglichkeit",
    1: "Begegnungsort",
    2: "Kreativität Diversität Nachhaltigkeit",
    3: "Bewahren Lernen",
    4: "DNB Video",
    5: "Papier Medium Buch",
    6: "Wissenschaft Dienstleistung Vielfalt",
    7: "Gelehrsamkeit",
    8: "Zugänglichkeit Metadaten",
    9: "Cloud Zugang Hörbücher"
}

# %%
import pyLDAvis.gensim_models
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word)
pyLDAvis.save_html(vis, name + 'LDATopics' + '_' + '.html') #_prechunked'+ str(prechunks)

# %%
from gensim.models import ldaseqmodel

def assign_topic(lda_model, corpus):
    topics = lda_model.get_document_topics(corpus)
    dominant_topics = [max(t, key=lambda x: x[1])[0] for t in topics]
    return dominant_topics

document_topics = assign_topic(lda_model, corpus)

# %%
# writing topic assignment into csv together with all docs

import csv

# Assuming you have document_texts, document_topics, and clusters from the previous steps

# Create a list to store the data
data_n = []

# Iterate through documents and their corresponding topics and clusters
for doc_num, (doc_text, topic) in enumerate(zip(commentframe, document_topics)):
    data_n.append([doc_num, topic, doc_text])

# Write data to CSV file
csv_file_path = name+"_topics_clusters.csv"
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    # Write headers
    writer.writerow(["docnum", "topicnum", "text"])
    # Write data
    writer.writerows(data_n)

# %%
# adding topic labels and writing to csv

import pandas as pd

# Read CSV into DataFrame
df = pd.read_csv(name+"_topics_clusters.csv")

# Add a new column 'TopicLabel' to the DataFrame
df['TopicLabel'] = df['topicnum'].map(topic_labels)

# Write the updated DataFrame to a new CSV file
df.to_csv(name+"_topics_clusters_with_labels.csv", index=False)

# %%
# generating barcharts showing document distribution per topic
dfbar = pd.read_csv(name+"_topics_clusters_with_labels.csv")

topic_label_counts = dfbar['TopicLabel'].value_counts()

plt.figure(figsize=(10, 6))
topic_label_counts.plot(kind='bar', color='skyblue')
plt.title('Topic Label Distribution')
plt.xlabel('Topic Label')
plt.ylabel('Count')
plt.tight_layout()
plt.savefig(name+"_DocsPerTopic_barchart.svg")
plt.show()

# %%
# generating barcharts showing document distribution per topic
dfbar = pd.read_csv(name+"_topics_clusters_with_labels.csv")
dfbar
# Out:
#      docnum  topicnum                                               text  \
# 0         0         3  Für DNB heißt mehr Jahre mehr Bücher. Mehr Büc...
# 1         1         5  Bibliotheken der Zukunft sollten "alles" anbie...
# 2         2         7              Nach wie vor starke Partnerin der ZDB
# 3         3         8            Fliegende Bücher, so nach Art Sushi Bar
# 4         4         3  Ein neues Medium, ein paar Erweiterungen, neue...
# ..      ...       ...                                                ...
# 112     112         8  → Gewünschte Ausleihdauer aussuchen & nach Abl...
# 113     113         4                                          Generell:
# 114     114         3  Bibliotheken sollten Orte der Begegnung für al...
# 115     115         0                        Für die Nationalbibliothek:
# 116     116         3  Ein offener Ort an dem man über die Vergangenh...
#
#                          TopicLabel
# 0                   Bewahren Lernen
# 1                Papier Medium Buch
# 2                     Gelehrsamkeit
# 3          Zugänglichkeit Metadaten
# 4                   Bewahren Lernen
# ..                              ...
# 112        Zugänglichkeit Metadaten
# 113                       DNB Video
# 114                 Bewahren Lernen
# 115  Digitalisierung Zugänglichkeit
# 116                 Bewahren Lernen
#
# [117 rows x 4 columns]

# %%
# determine word frequencies

import pandas as pd
from collections import Counter
import re


def get_word_frequencies_from_list_of_lists(list_of_lists):
    # Concatenate all words from the list of lists into a single list
    all_words = [word for sublist in list_of_lists for word in sublist if word != '--']

    # Calculate word frequencies using Counter
    word_frequencies = Counter(all_words)

    return word_frequencies

# Example usage
frequencies = get_word_frequencies_from_list_of_lists(data_final)

# Print word frequencies
for word, frequency in frequencies.items():
    print(f"{word}: {frequency}")
# Out:
# DNB: 10
# heißen: 1
# Jahr: 1
# Buch: 27
# geben: 4
# aufbewahren: 2
# Bibliothek: 32
# Zukunft: 10
# anbieten: 1
# Mensch: 7
# Papier: 4
# Hand: 1
# halten: 1
# E-Book-Reader: 1
# platzsparend: 1
# Ergänzung: 1
# Interaktive: 1
# Medium: 4
# interessant: 1
# weiterhin: 3
# gerne: 3
# DVDs: 1
# Hörbücher: 3
# schön: 2
# Lesebereich: 1
# locken: 1
# stark: 1
# Partnerin: 1
# ZDB: 1
# fliegend: 1
# Art: 2
# Sushi: 1
# Bar: 1
# neu: 4
# Erweiterung: 1
# Aufbewahrungsmöglichkeit: 1
# Kooperation: 2
# Zusammenarbeit: 3
# ortsungebund: 1
# Zugänglichkeit: 2
# Information: 3
# bieten: 3
# bitte: 1
# eröffn: 1
# Standort: 2
# z.B.: 2
# Hamburg: 2
# umzuschauen: 1
# toll: 2
# müs: 1
# eröffnen: 1
# einladend: 1
# Ort: 17
# Verweil: 1
# Bilrdschirme: 1
# schnell: 1
# Recherche: 1
# Stöber: 1
# Lese: 2
# Genieße: 1
# Gelehrsamkeit: 1
# Kommunikation: 2
# Meinungsaustausch: 1
# Design: 1
# Zentraler: 1
# Dienstleistungs-)Funktion: 1
# Bibliothekswesen: 1
# Bundesebene: 1
# u.a.: 1
# Verknüpfung: 1
# Bibltioheke: 1
# unterschiedlich: 2
# Trägerschaft: 1
# wissenschaftlich: 2
# Land: 1
# öffentlich: 3
# meist: 1
# Kommune: 1
# Fokus: 1
# Inhalts-/Sacherschließung: 1
# Metadat: 1
# wesentlich: 1
# Mehrwert: 1
# Auffindbarkeit: 1
# Gaming: 1
# Lab: 1
# aufbrech: 1
# alt: 5
# Muster: 1
# Tier: 1
# Schule: 1
# eigenverantwortlich: 1
# arbeiten: 1
# Bürokratie: 1
# Hierarchie-Eben: 1
# klar: 1
# Augenhöhe: 1
# intigrieren: 1
# Lampe: 1
# leuchtend: 1
# Seite: 2
# Bilderbücher: 1
# Lebensgrösse: 1
# einzeln: 1
# aufstellen: 1
# sodass: 1
# Geschichte: 2
# durchlaufen: 1
# bestimmen: 1
# Roboter: 1
# bringen: 3
# unendlich: 1
# Digital: 3
# Sprache: 1
# Relevanz: 2
# schwinden: 1
# bleiben: 3
# modern: 1
# Computer: 1
# niemals: 1
# greifbar: 1
# Bildung: 1
# Kreativität: 2
# ersetzen: 1
# Digitalisierung: 2
# Vereinfachung: 1
# physisch: 1
# vollkommen: 1
# unersetzbar: 1
# komplett: 1
# Gedächtnis: 2
# Internet: 1
# frei: 1
# zugänglich: 1
# jederzeit: 2
# verfügbar: 1
# technisch: 1
# Schnittstelle: 1
# Stand: 1
# Technik: 2
# einfach: 1
# nutzbar: 1
# beliebig: 1
# Suchfunktion: 1
# Gemeinwohl: 1
# wünschen: 4
# Video: 2
# Nation: 1
# Bibliographie: 1
# Hierarchie: 1
# Klassifikatio: 1
# Schlagwörter: 1
# Rolle: 1
# spielen: 2
# Meta-Suchmaschine: 1
# Inhalt: 1
# digital: 2
# Raum: 5
# Austausch: 3
# kommerziell: 1
# Ruhe: 2
# Multimedialer: 1
# Erfahrungsort: 1
# aufhalten: 1
# treffen: 4
# Gemeinschaft: 1
# zusammenbringen: 1
# Vermittlung: 1
# Kenntnis: 1
# Ope: 3
# library: 2
# World: 2
# kostenlos: 3
# Bibliotheksausweise: 1
# freuen: 2
# Universität: 1
# København: 1
# Schatz: 1
# digitalisieren: 2
# sehen: 1
# Kulturgut: 1
# wahren: 1
# Buchform: 1
# persönlich: 1
# Betreuung: 1
# überall: 1
# unabhängig: 1
# Verlag: 1
# finden: 1
# Nationalbibliothek: 2
# verlieren: 1
# zukunftswunsch: 1
# Verfügung: 1
# stehen: 1
# verknüpfen: 1
# wis: 1
# wünsch: 1
# Darstellung: 1
# Autoren-/Personennetzwerk: 1
# Verbindung: 1
# Autor: 1
# untereinander: 3
# nachvollziehen: 1
# lässt: 1
# Theaterstück: 1
# speichern: 1
# schauen: 1
# Orchester: 1
# Bücherregal: 1
# integrieren: 1
# Bildschirmen: 1
# verstecken: 1
# Erscheinung: 1
# treten: 1
# inklusiv: 1
# Charakter: 1
# fach: 1
# milieuübergreifend: 1
# akademisch: 1
# bewahren: 1
# trinken: 1
# Lesesaal: 2
# nett: 1
# dringend: 1
# nötig: 1
# hoffentlich: 1
# echt: 1
# ausstrahlen: 1
# supergut: 1
# Einrichtung: 1
# gemeinsam: 3
# leiden: 1
# Lindere: 1
# angeblich: 1
# lächeln: 2
# Möglichkeit: 2
# recherchieren: 1
# vielfältig: 2
# Auswahl: 1
# zustellen: 1
# denken: 1
# Vision: 1
# Arbeitgeber: 1
# Mitarbeiter*inn: 1
# schätzen: 1
# fördern: 1
# vertrauensvoll: 1
# umgehen: 1
# aufmerksam: 1
# Auftritt: 1
# Anfang: 1
# Ausstellung: 1
# afrikanisch: 1
# deutsch: 2
# Schriftsteller: 1
# Kolonialzeit: 1
# Afrika: 1
# Bücherausleihe: 1
# Begegnung: 2
# Nachhaltigkeit: 1
# Ding: 1
# teilen: 1
# Diversität: 1
# jung: 2
# Think: 1
# The: 2
# Book: 2
# Survive: 1
# There: 1
# Read: 1
# Engere: 1
# Vernetzung: 1
# Coverfoto: 1
# DNB-Datensatz: 1
# Versuch: 1
# entziffern: 1
# Biblioteca: 1
# dovrebbe: 1
# esseren: 1
# luogon: 1
# aperto: 1
# Giovani: 1
# incontro(?)/menutia: 1
# Jugend: 1
# Abend: 1
# öffnen: 2
# unterhalten: 1
# Zugang: 4
# Welt: 1
# Weg: 2
# hineinzugehen: 1
# Klick: 1
# erhalten: 1
# zzu: 1
# verlassen: 1
# Wikipedia: 1
# Buchverlinkung: 1
# etc.: 1
# Digitaler: 1
# Publikationsformen: 1
# auskommen: 1
# Angebot: 1
# unglaublich: 1
# Vielfalt: 2
# Leute: 1
# altmodisch: 1
# Kanal: 1
# Herrschaft: 1
# Wissenssammlung: 1
# Rückblick: 1
# Leben: 1
# nehmen: 1
# Toll: 1
# hochwertig: 1
# Literaturveranstaltung: 1
# Kriminialroman: 1
# kämpfen: 1
# Ausweis: 1
# Besuch: 1
# Karte: 1
# flexibel: 1
# Arbeitsplatz: 1
# lernen: 4
# bestmöglich: 1
# unterstützen: 1
# Konzept: 1
# Medienkompetenz: 1
# lehren: 1
# Format: 1
# Jede*n: 1
# klein: 3
# Bruder: 1
# legobauen: 1
# Eltern: 1
# Geschäftsreise: 1
# Taschenbücher: 1
# großformatig: 1
# Kinderbücher/-bild: 1
# Video-)Spiel: 1
# nirgends: 1
# Bedürfnis: 1
# national: 1
# Treffen: 1
# Auszubildender: 1
# hintergrundgeräusch: 1
# Musik: 1
# Hintergrund: 1
# LED: 1
# Beanbag: 1
# gedimmen: 1
# Licht: 1
# Coffee-Shop: 1
# Wohnzimmer: 1
# Stadt: 1
# Dorf: 1
# Grundgesetz: 1
# verankern: 1
# harmonisch: 1
# vereinen: 1
# Lobbyarbeit: 1
# rechtlich: 1
# ermoglichen: 1
# Remote-Access: 1
# urheberrechtlich: 1
# schützen: 2
# Material: 1
# ermöglichen: 2
# eher: 1
# Stadtbibliothek: 1
# lebendig: 1
# Umgebung: 1
# Pflanze: 1
# Fremdsprache: 1
# Ausbau: 1
# elektronisch: 1
# Ausleih: 1
# Modular: 1
# Stillesaal: 1
# Schreibsaal: 1
# kooperativ: 1
# Schreiben: 1
# Öffn: 1
# besonderer: 1
# Schreibanläs: 1
# nicht-wissenschaftlich: 1
# begegnen: 1
# Archivfunktion: 1
# wichtig: 1
# Server: 1
# abstürzen: 1
# Zugriff: 1
# ähnlich: 1
# Saatgut-Safeding: 1
# Grönland: 1
# liegen: 1
# Hängesessel: 1
# Entspann: 1
# iPads: 1
# eBooks: 1
# Station: 1
# Podcast: 1
# hören: 1
# malen: 1
# Zeitmanagement: 1
# Schulung: 1
# Lesung: 1
# passend: 1
# Tag: 1
# Tür: 1
# Begegnungsstätte: 1
# lesen: 1
# Forsch: 1
# schreiben: 1
# Mahngebühr: 1
# Büchereien: 1
# 360-Grad-Führung: 1
# Lesesal: 1
# Magazin: 1
# beweglich: 1
# Regal: 1
# körperlich: 1
# einschränken: 1
# bedienen: 1
# ober: 1
# Regalreihen: 1
# Elefantenfüße: 1
# stellen: 1
# Hilfe: 1
# bitten: 1
# verschied: 1
# Kultur: 1
# Problem: 1
# austausch: 1
# Gerät: 1
# Sprachbarrier: 1
# helfen: 1
# Kind: 1
# Lesen: 1
# Azubis: 1
# Praktikum: 1
# Frankfurt: 1
# Leipzig: 1
# kostenfreier: 1
# Fleißarbeit: 1
# katalogisieren: 1
# outsourcen: 1
# Arbeit: 1
# einsetzen: 1
# still: 1
# Lebendigkeit: 1
# Cloud: 2
# Evtl: 1
# Brille: 1
# Konopfdruck: 1
# beamen: 3
# aussuchen: 2
# Drohne: 1
# Haus: 1
# bestellen: 1
# Knopfdruck: 1
# Runter: 1
# Ausleihdauer: 1
# Ablauf: 1
# Generell: 1
# Rückzugsort: 1
# Kontakt: 1
# knüpfen: 1
# Hinsicht: 1
# leben: 1
# Vergangenheit: 1
# kostenfrein: 1

# %%
# writing word frequencies to txt

frequencies_file_path = name+'_word_frequencies.txt'

# Example usage
with open(frequencies_file_path, 'w') as file:
    for word, frequency in frequencies.items():
        file.write(f"{word}: {frequency}\n")

print(f"Worthäufigkeiten in folgende Datei geschrieben: {frequencies_file_path}")
# Out:
# Worthäufigkeiten in folgende Datei geschrieben: dnbf_visionen23_word_frequencies.txt

# %%
# wordcloud generator

from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(frequencies)

# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis numbers and ticks
plt.savefig(name+'_WordcloudFrequencies.svg')
plt.show()
# Out:
# /home/freybek/envs/jupyterenv/lib/python3.10/site-packages/wordcloud/wordcloud.py:106: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   self.colormap = plt.cm.get_cmap(colormap)
