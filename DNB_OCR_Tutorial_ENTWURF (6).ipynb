# %% [markdown]
# # DNBLab Jupyter Notebook Tutorial

# %% [markdown]
# ## OCR: Datenabfrage, Auslieferung und Textanalyse

# %% [markdown]
# Entwurf: Dieses DNBLab-Tutorial beschreibt eine Beispielabfrage zu digitalisierten Inhaltsverzeichnissen über die SRU-Schnittstelle. Das Tutorial umfasst eine exemplarische Abfrage, das temporäre Speichern der Inhaltsverzeichnisse als Textdateien und Durchsuchen der Volltexte nach einem beliebigen Stichwort. In der Jupyter Notebook Umgebung kann der dokumentierte Code direkt ausgeführt und angepasst werden.

# %% [markdown]
# ## Einrichten der Arbeitsumgebung <a class="anchor" id="Teil1"></a>
#
# Um die Arbeitsumgebung für die folgenden Schritte passend einzurichten, sollten zunächst die benötigten Python-Bibliotheken importiert werden. Für Anfragen über die SRU-Schnittstelle wird BeautifulSoup https://www.crummy.com/software/BeautifulSoup/ und zur Verarbeitung der XML-Daten etree https://docs.python.org/3/library/xml.etree.elementtree.html verwendet. Mit Pandas https://pandas.pydata.org/ können Elemente aus dem MARC21-Format ausgelesen werden.

# %%
import requests
from bs4 import BeautifulSoup as soup
import unicodedata
from lxml import etree
import pandas as pd

# %% [markdown]
# ## SRU-Abfrage mit Ausgabe in MARC21-xml<a class="anchor" id="Teil2"></a>
#
# Die Funktion dnb_sru nimmt den Paramter "query" der SRU-Abfrage entgegen und liefert alle Ergebnisse als eine Liste von Records aus. Bei mehr als 100 Records werden weitere Datensätze mit "&startRecord=101" abgerufen (mögliche Werte 1 bis 99.000). Weitere Informationen und Funktionen der SRU- Schnittstelle werden unter https://www.dnb.de/sru beschrieben.

# %%
def dnb_sru(query):
    
    base_url = "https://services.dnb.de/sru/dnb"
    params = {'recordSchema' : 'MARC21-xml',
          'operation': 'searchRetrieve',
          'version': '1.1',
          'maximumRecords': '100',
          'query': query
         }
    r = requests.get(base_url, params=params)
    xml = soup(r.content)
    records = xml.find_all('record', {'type':'Bibliographic'})
    
    if len(records) < 100:
        
        return records
    
    else:
        
        num_results = 100
        i = 101
        while num_results == 100:
            
            params.update({'startRecord': i})
            r = requests.get(base_url, params=params)
            xml = soup(r.content)
            new_records = xml.find_all('record', {'type':'Bibliographic'})
            records+=new_records
            i+=100
            num_results = len(new_records)
            
        return records

# %% [markdown]
# ### Durchsuchen eines MARC-Feldes<a class="anchor" id="Teil3"></a>
#
# Die Funktion parse_records nimmt als Parameter jeweils ein Record entgegen und sucht über xpath die gewünschte Informationen heraus und liefert diese als Dictionary zurück. Die Schlüssel-Werte-Paare können beliebig agepasst und erweitert werden. In diesem Fall werden nur die Permalinks zu den digitalisierten Inhaltsverzeichnissen als "link" ausgegeben.

# %%
def parse_record(record):
    
    ns = {"marc":"http://www.loc.gov/MARC21/slim"}
    xml = etree.fromstring(unicodedata.normalize("NFC", str(record)))
    
    #link
    link = xml.xpath("marc:datafield[@tag = '856']/marc:subfield[@code = 'u']", namespaces=ns)
    
    try:
        link = link[0].text
    except:
        link = "unknown"
        
    meta_dict = {"link":link + '/text'}
    
    return meta_dict

# %% [markdown]
# Über verschiedenen Indices https://services.dnb.de/sru/dnb?operation=explain&version=1.1 kann die SRU-Abfrage "dnb_sru" mittels CQL https://www.dnb.de/DE/Service/Hilfe/Katalog/kataloghilfeExpertensuche.html eingeschränkt werden. Im Folgenden Code wird die Abfrage über das Stichwort "Sandwespe" im Volltextindex der digitalisierten Inhaltsverzeichnisse eingeschränkt. Durch Anpassen der SRU-Abfrage kann die Trefferliste beliebig geändert werden.

# %%
records = dnb_sru('inh=Nähmaschine')
print(len(records), 'Ergebnisse')
# Out:
# 750 Ergebnisse

# %% [markdown]
# ## Beispielanzeige zur weiteren Bearbeitung <a class="anchor" id="Teil4"></a>
#
# Mit der Bibliothek Pandas für Python wird das Ergebnis (Dictionary-Element "link") als Dataframe ausgegeben.

# %%
output = [parse_record(record) for record in records]
df = pd.DataFrame(output)
df
# Out:
#                                                   link
# 0    http://deposit.dnb.de/cgi-bin/dokserv?id=043b0...
# 1    http://deposit.dnb.de/cgi-bin/dokserv?id=f6d16...
# 2    http://deposit.dnb.de/cgi-bin/dokserv?id=1b6e2...
# 3    http://deposit.dnb.de/cgi-bin/dokserv?id=1f524...
# 4    http://deposit.dnb.de/cgi-bin/dokserv?id=f4e7e...
# ..                                                 ...
# 745                https://d-nb.info/363621814/04/text
# 746                https://d-nb.info/361208944/04/text
# 747                https://d-nb.info/362024774/04/text
# 748                https://d-nb.info/580171256/04/text
# 749                https://d-nb.info/579860299/04/text
#
# [750 rows x 1 columns]

# %% [markdown]
# Die Ausgabe der ermittelten Links kann je nach Bedarf über verschiedene Funktionen erfolgen:

# %%
#print(df.to_string(index=False))
#HTML(df.to_html(index=False))
#document = df.to_dict(orient='list')
#print(document)

# %% [markdown]
# Mit der folgenden Funktion df.to_csv() werden die Ergebnisse als "links.csv" in das Jupyter-Verzeichnins der Einstiegsseite abgelegt und können dort heruntergeladen werden.

# %%
df.to_csv("links.csv", index=False)

# %% [markdown]
# Mit wget werden alle in der CSV-Datei gespeicherten Links heruntergeladen und als Textdateien (text, text.1, text.2, usw.) im temporären Jupyter-Verzeichnis gespeichert.

# %%
# !wget -i links.csv
# Out:
# --2021-08-05 08:31:49--  http://link/
# Resolving link (link)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘link’
# --2021-08-05 08:31:49--  http://deposit.dnb.de/cgi-bin/dokserv?id=043b027d59f04e619522dde80bd12406&prov=M&dok_var=1&dok_ext=htm/text
# Resolving deposit.dnb.de (deposit.dnb.de)... 193.175.100.44
# Connecting to deposit.dnb.de (deposit.dnb.de)|193.175.100.44|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dokserv?id=043b027d59f04e619522dde80bd12406&prov=M&dok_var=1&dok_ext=htm%2Ftext’
#
# dokserv?id=043b027d     [ <=>                ]     910  --.-KB/s    in 0s
#
# 2021-08-05 08:31:49 (29.7 MB/s) - ‘dokserv?id=043b027d59f04e619522dde80bd12406&prov=M&dok_var=1&dok_ext=htm%2Ftext’ saved [910]
#
# --2021-08-05 08:31:49--  http://deposit.dnb.de/cgi-bin/dokserv?id=f6d160d66f69408bb6fcae6a33a8d0a6&prov=M&dok_var=1&dok_ext=htm/text
# Reusing existing connection to deposit.dnb.de:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dokserv?id=f6d160d66f69408bb6fcae6a33a8d0a6&prov=M&dok_var=1&dok_ext=htm%2Ftext’
#
# dokserv?id=f6d160d6     [ <=>                ]   1.07K  --.-KB/s    in 0s
#
# 2021-08-05 08:31:49 (55.7 MB/s) - ‘dokserv?id=f6d160d66f69408bb6fcae6a33a8d0a6&prov=M&dok_var=1&dok_ext=htm%2Ftext’ saved [1096]
#
# --2021-08-05 08:31:49--  http://deposit.dnb.de/cgi-bin/dokserv?id=1b6e232641014addbdf503cada1cb600&prov=M&dok_var=1&dok_ext=htm/text
# Reusing existing connection to deposit.dnb.de:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dokserv?id=1b6e232641014addbdf503cada1cb600&prov=M&dok_var=1&dok_ext=htm%2Ftext’
#
# dokserv?id=1b6e2326     [ <=>                ]   2.83K  --.-KB/s    in 0s
#
# 2021-08-05 08:31:49 (122 MB/s) - ‘dokserv?id=1b6e232641014addbdf503cada1cb600&prov=M&dok_var=1&dok_ext=htm%2Ftext’ saved [2895]
#
# --2021-08-05 08:31:49--  http://deposit.dnb.de/cgi-bin/dokserv?id=1f524ca23fa54a509bf521eec416d150&prov=M&dok_var=1&dok_ext=htm/text
# Reusing existing connection to deposit.dnb.de:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dokserv?id=1f524ca23fa54a509bf521eec416d150&prov=M&dok_var=1&dok_ext=htm%2Ftext’
#
# dokserv?id=1f524ca2     [ <=>                ]   1.12K  --.-KB/s    in 0s
#
# 2021-08-05 08:31:49 
04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1694 (1.7K) [text/plain]
# Saving to: ‘text.19’
#
# text.19             100%[===================>]   1.65K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:00 (142 MB/s) - ‘text.19’ saved [1694/1694]
#
# --2021-08-05 08:32:00--  https://d-nb.info/1184819041/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1219 (1.2K) [text/plain]
# Saving to: ‘text.20’
#
# text.20             100%[===================>]   1.19K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:00 (77.5 MB/s) - ‘text.20’ saved [1219/1219]
#
# --2021-08-05 08:32:00--  https://d-nb.info/1172659990/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2020 (2.0K) [text/plain]
# Saving to: ‘text.21’
#
# text.21             100%[===================>]   1.97K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:01 (55.2 MB/s) - ‘text.21’ saved [2020/2020]
#
# --2021-08-05 08:32:01--  https://d-nb.info/1198500778/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12520 (12K) [text/plain]
# Saving to: ‘text.22’
#
# text.22             100%[===================>]  12.23K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:32:01 (804 KB/s) - ‘text.22’ saved [12520/12520]
#
# --2021-08-05 08:32:01--  http://deposit.dnb.de/cgi-bin/dokserv?id=3d0b5c94614a4a8aa0dcbda4be4ac1ca&prov=M&dok_var=1&dok_ext=htm/text
# Connecting to deposit.dnb.de (deposit.dnb.de)|193.175.100.44|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dokserv?id=3d0b5c94614a4a8aa0dcbda4be4ac1ca&prov=M&dok_var=1&dok_ext=htm%2Ftext’
#
# dokserv?id=3d0b5c94     [ <=>                ]   1.04K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:01 (47.9 MB/s) - ‘dokserv?id=3d0b5c94614a4a8aa0dcbda4be4ac1ca&prov=M&dok_var=1&dok_ext=htm%2Ftext’ saved [1068]
#
# --2021-08-05 08:32:01--  http://deposit.dnb.de/cgi-bin/dokserv?id=3f8addb899cb490eb6163c703f427d5a&prov=M&dok_var=1&dok_ext=htm/text
# Reusing existing connection to deposit.dnb.de:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dokserv?id=3f8addb899cb490eb6163c703f427d5a&prov=M&dok_var=1&dok_ext=htm%2Ftext’
#
# dokserv?id=3f8addb8     [ <=>                ]     782  --.-KB/s    in 0s
#
# 2021-08-05 08:32:01 (35.6 MB/s) - ‘dokserv?id=3f8addb899cb490eb6163c703f427d5a&prov=M&dok_var=1&dok_ext=htm%2Ftext’ saved [782]
#
# --2021-08-05 08:32:01--  https://d-nb.info/1170088635/04/text
# Connecting to d-nb.info (d-nb.info)|193.175.100.223|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 757 [text/plain]
# Saving to: ‘text.23’
#
# text.23             100%[===================>]     757  --.-KB/s    in 0s
#
# 2021-08-05 08:32:02 (54.4 MB/s) - ‘text.23’ saved [757/757]
#
# --2021-08-05 08:32:02--  https://d-nb.info/1181981832/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1738 (1.7K) [text/plain]
# Saving to: ‘text.24’
#
# text.24             100%[===================>]   1.70K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:02 (47.2 MB/s) - ‘text.24’ saved [1738/1738]
#
# --2021-08-05 08:32:02--  https://d-nb.info/1184413207/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5072 (5.0K) [text/plain]
# Saving to: ‘text.25’
#
# text.25             100%[===================>]   4.95K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:03 (72.3 MB/s) - ‘text.25’ saved [5072/5072]
#
# --2021-08-05 08:32:03--  https://d-nb.info/116942709X/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1097 (1.1K) [text/plain]
# Saving to: ‘text.26’
#
# text.26             100%[===================>]   1.07K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:03 (91.9 MB/s) - ‘text.26’ saved [1097/1097]
#
# --2021-08-05 08:32:03--  https://d-nb.info/1171547307/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6941 (6.8K) [text/plain]
# Saving to: ‘text.27’
#
# text.27             100%[===================>]   6.78K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:03 (94.7 MB/s) - ‘text.27’ saved [6941/6941]
#
# --2021-08-05 08:32:03--  http://deposit.dnb.de/cgi-bin/dokserv?id=580901362c0748a19e33ba1027278036&prov=M&dok_var=1&dok_ext=htm/text
# Connecting to deposit.dnb.de (deposit.dnb.de)|193.175.100.44|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dokserv?id=580901362c0748a19e33ba1027278036&prov=M&dok_var=1&dok_ext=htm%2Ftext’
#
# dokserv?id=58090136     [ <=>                ]   1.22K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:04 (51.9 MB/s) - ‘dokserv?id=580901362c0748a19e33ba1027278036&prov=M&dok_var=1&dok_ext=htm%2Ftext’ saved [1252]
#
# --2021-08-05 08:32:04--  https://d-nb.info/117274940X/04/text
# Connecting to d-nb.info (d-nb.info)|193.175.100.223|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 961 [text/plain]
# Saving to: ‘text.28’
#
# text.28             100%[===================>]     961  --.-KB/s    in 0s
#
# 2021-08-05 08:32:04 (69.7 MB/s) - ‘text.28’ saved [961/961]
#
# --2021-08-05 08:32:04--  https://d-nb.info/1186919493/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5871 (5.7K) [text/plain]
# Saving to: ‘text.29’
#
# text.29             100%[===================>]   5.73K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:04 (135 MB/s) - ‘text.29’ saved [5871/5871]
#
# --2021-08-05 08:32:04--  https://d-nb.info/1199130001/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 889 [text/plain]
# Saving to: ‘text.30’
#
# text.30             100%[===================>]     889  --.-KB/s    in 0s
#
# 2021-08-05 08:32:05 (68.0 MB/s) - ‘text.30’ saved [889/889]
#
# --2021-08-05 08:32:05--  https://d-nb.info/1175024171/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4733 (4.6K) [text/plain]
# Saving to: ‘text.31’
#
# text.31             100%[===================>]   4.62K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:05 (119 MB/s) - ‘text.31’ saved [4733/4733]
#
# --2021-08-05 08:32:05--  https://d-nb.info/1184819084/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1426 (1.4K) [text/plain]
# Saving to: ‘text.32’
#
# text.32             100%[===================>]   1.39K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:05 (114 MB/s) - ‘text.32’ saved [1426/1426]
#
# --2021-08-05 08:32:05--  https://d-nb.info/1192581601/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 340 [text/plain]
# Saving to: ‘text.33’
#
# text.33             100%[===================>]     340  --.-KB/s    in 0s
#
# 2021-08-05 08:32:05 (28.7 MB/s) - ‘text.33’ saved [340/340]
#
# --2021-08-05 08:32:05--  https://bpa-media.de//text
# Resolving bpa-media.de (bpa-media.de)... 185.237.67.229
# Connecting to bpa-media.de (bpa-media.de)|185.237.67.229|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://bpa-media.de/text [following]
# --2021-08-05 08:32:06--  https://bpa-media.de/text
# Reusing existing connection to bpa-media.de:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘text.34’
#
# text.34                 [ <=>                ]   3.56K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:06 (58.2 MB/s) - ‘text.34’ saved [3648]
#
# --2021-08-05 08:32:06--  http://deposit.dnb.de/cgi-bin/dokserv?id=06d804bd8bf34e78908606fa3730487e&prov=M&dok_var=1&dok_ext=htm/text
# Connecting to deposit.dnb.de (deposit.dnb.de)|193.175.100.44|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dokserv?id=06d804bd8bf34e78908606fa3730487e&prov=M&dok_var=1&dok_ext=htm%2Ftext’
#
# dokserv?id=06d804bd     [ <=>                ]     814  --.-KB/s    in 0s
#
# 2021-08-05 08:32:06 (34.4 MB/s) - ‘dokserv?id=06d804bd8bf34e78908606fa3730487e&prov=M&dok_var=1&dok_ext=htm%2Ftext’ saved [814]
#
# --2021-08-05 08:32:06--  https://d-nb.info/1184817731/04/text
# Connecting to d-nb.info (d-nb.info)|193.175.100.223|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 836 [text/plain]
# Saving to: ‘text.35’
#
# text.35             100%[===================>]     836  --.-KB/s    in 0s
#
# 2021-08-05 08:32:06 (60.0 MB/s) - ‘text.35’ saved [836/836]
#
# --2021-08-05 08:32:06--  https://d-nb.info/1167182952/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34071 (33K) [text/plain]
# Saving to: ‘text.36’
#
# text.36             100%[===================>]  33.27K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:32:07 (2.03 MB/s) - ‘text.36’ saved [34071/34071]
#
# --2021-08-05 08:32:07--  https://d-nb.info/1183980639/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11154 (11K) [text/plain]
# Saving to: ‘text.37’
#
# text.37             100%[===================>]  10.89K  --.-KB/s    in 0s
#
# 2021-08-05 08:32:07 (57.1 MB/s) - ‘text.37’ saved [11154/11154]
#
# --2021-08-05 08:32:07--  https://d-nb.info/1179954505/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 970 [text/plain]
# Saving to: ‘text.38’
#
# text.38             100%[===================>]     970  --.-KB/s    in 0s
#
# 2021-08-05 08:32:07 (78.5 MB/s) - ‘text.38’ saved [970/970]
#
# --2021-08-05 08:32:07--  https://d-nb.info/1184314241/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 
  --.-KB/s    in 0s
#
# 2021-08-05 08:35:05 (156 MB/s) - ‘text.623’ saved [7431/7431]
#
# --2021-08-05 08:35:05--  https://d-nb.info/361638957/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4759 (4.6K) [text/plain]
# Saving to: ‘text.624’
#
# text.624            100%[===================>]   4.65K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:05 (54.8 MB/s) - ‘text.624’ saved [4759/4759]
#
# --2021-08-05 08:35:05--  https://d-nb.info/361638965/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4289 (4.2K) [text/plain]
# Saving to: ‘text.625’
#
# text.625            100%[===================>]   4.19K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:05 (37.4 MB/s) - ‘text.625’ saved [4289/4289]
#
# --2021-08-05 08:35:05--  https://d-nb.info/361297890/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4173 (4.1K) [text/plain]
# Saving to: ‘text.626’
#
# text.626            100%[===================>]   4.08K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:05 (101 MB/s) - ‘text.626’ saved [4173/4173]
#
# --2021-08-05 08:35:05--  https://d-nb.info/363252681/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4758 (4.6K) [text/plain]
# Saving to: ‘text.627’
#
# text.627            100%[===================>]   4.65K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:06 (54.1 MB/s) - ‘text.627’ saved [4758/4758]
#
# --2021-08-05 08:35:06--  https://d-nb.info/363635742/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19951 (19K) [text/plain]
# Saving to: ‘text.628’
#
# text.628            100%[===================>]  19.48K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:06 (1.20 MB/s) - ‘text.628’ saved [19951/19951]
#
# --2021-08-05 08:35:06--  https://d-nb.info/580813606/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3354 (3.3K) [text/plain]
# Saving to: ‘text.629’
#
# text.629            100%[===================>]   3.28K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:07 (81.1 MB/s) - ‘text.629’ saved [3354/3354]
#
# --2021-08-05 08:35:07--  https://d-nb.info/579388875/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2689 (2.6K) [text/plain]
# Saving to: ‘text.630’
#
# text.630            100%[===================>]   2.63K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:07 (69.0 MB/s) - ‘text.630’ saved [2689/2689]
#
# --2021-08-05 08:35:07--  https://d-nb.info/365868876/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16662 (16K) [text/plain]
# Saving to: ‘text.631’
#
# text.631            100%[===================>]  16.27K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:07 (1.02 MB/s) - ‘text.631’ saved [16662/16662]
#
# --2021-08-05 08:35:07--  https://d-nb.info/991280555/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10614 (10K) [text/plain]
# Saving to: ‘text.632’
#
# text.632            100%[===================>]  10.37K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:07 (64.2 MB/s) - ‘text.632’ saved [10614/10614]
#
# --2021-08-05 08:35:07--  https://d-nb.info/361715986/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19540 (19K) [text/plain]
# Saving to: ‘text.633’
#
# text.633            100%[===================>]  19.08K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:08 (1.17 MB/s) - ‘text.633’ saved [19540/19540]
#
# --2021-08-05 08:35:08--  https://d-nb.info/580910865/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12730 (12K) [text/plain]
# Saving to: ‘text.634’
#
# text.634            100%[===================>]  12.43K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:08 (72.8 MB/s) - ‘text.634’ saved [12730/12730]
#
# --2021-08-05 08:35:08--  https://d-nb.info/368208354/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12043 (12K) [text/plain]
# Saving to: ‘text.635’
#
# text.635            100%[===================>]  11.76K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:08 (60.4 MB/s) - ‘text.635’ saved [12043/12043]
#
# --2021-08-05 08:35:08--  https://d-nb.info/361067356/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18564 (18K) [text/plain]
# Saving to: ‘text.636’
#
# text.636            100%[===================>]  18.13K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:08 (1.10 MB/s) - ‘text.636’ saved [18564/18564]
#
# --2021-08-05 08:35:08--  https://d-nb.info/570151104/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3263 (3.2K) [text/plain]
# Saving to: ‘text.637’
#
# text.637            100%[===================>]   3.19K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:09 (35.4 MB/s) - ‘text.637’ saved [3263/3263]
#
# --2021-08-05 08:35:09--  https://d-nb.info/361081634/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1694 (1.7K) [text/plain]
# Saving to: ‘text.638’
#
# text.638            100%[===================>]   1.65K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:09 (137 MB/s) - ‘text.638’ saved [1694/1694]
#
# --2021-08-05 08:35:09--  https://d-nb.info/361548354/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2730 (2.7K) [text/plain]
# Saving to: ‘text.639’
#
# text.639            100%[===================>]   2.67K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:10 (66.5 MB/s) - ‘text.639’ saved [2730/2730]
#
# --2021-08-05 08:35:10--  https://d-nb.info/366134248/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13396 (13K) [text/plain]
# Saving to: ‘text.640’
#
# text.640            100%[===================>]  13.08K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:10 (842 KB/s) - ‘text.640’ saved [13396/13396]
#
# --2021-08-05 08:35:10--  https://d-nb.info/991241649/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 17138 (17K) [text/plain]
# Saving to: ‘text.641’
#
# text.641            100%[===================>]  16.74K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:10 (1.05 MB/s) - ‘text.641’ saved [17138/17138]
#
# --2021-08-05 08:35:10--  https://d-nb.info/361681984/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9236 (9.0K) [text/plain]
# Saving to: ‘text.642’
#
# text.642            100%[===================>]   9.02K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:10 (66.8 MB/s) - ‘text.642’ saved [9236/9236]
#
# --2021-08-05 08:35:10--  https://d-nb.info/579163806/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4482 (4.4K) [text/plain]
# Saving to: ‘text.643’
#
# text.643            100%[===================>]   4.38K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:11 (49.5 MB/s) - ‘text.643’ saved [4482/4482]
#
# --2021-08-05 08:35:11--  https://d-nb.info/363633731/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4314 (4.2K) [text/plain]
# Saving to: ‘text.644’
#
# text.644            100%[===================>]   4.21K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:11 (15.7 MB/s) - ‘text.644’ saved [4314/4314]
#
# --2021-08-05 08:35:11--  https://d-nb.info/362481504/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2059 (2.0K) [text/plain]
# Saving to: ‘text.645’
#
# text.645            100%[===================>]   2.01K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:11 (55.8 MB/s) - ‘text.645’ saved [2059/2059]
#
# --2021-08-05 08:35:11--  https://d-nb.info/366157108/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3104 (3.0K) [text/plain]
# Saving to: ‘text.646’
#
# text.646            100%[===================>]   3.03K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:12 (33.4 MB/s) - ‘text.646’ saved [3104/3104]
#
# --2021-08-05 08:35:12--  https://d-nb.info/362474818/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2321 (2.3K) [text/plain]
# Saving to: ‘text.647’
#
# text.647            100%[===================>]   2.27K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:12 (63.6 MB/s) - ‘text.647’ saved [2321/2321]
#
# --2021-08-05 08:35:12--  https://d-nb.info/362474826/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2704 (2.6K) [text/plain]
# Saving to: ‘text.648’
#
# text.648            100%[===================>]   2.64K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:12 (71.7 MB/s) - ‘text.648’ saved [2704/2704]
#
# --2021-08-05 08:35:12--  https://d-nb.info/579388867/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2308 (2.3K) [text/plain]
# Saving to: ‘text.649’
#
# text.649            100%[===================>]   2.25K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:12 (66.4 MB/s) - ‘text.649’ saved [2308/2308]
#
# --2021-08-05 08:35:12--  https://d-nb.info/987813153/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 20252 (20K) [text/plain]
# Saving to: ‘text.650’
#
# text.650            100%[===================>]  19.78K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:13 (1.22 MB/s) - ‘text.650’ saved [20252/20252]
#
# --2021-08-05 08:35:13--  https://d-nb.info/365743291/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15241 (15K) [text/plain]
# Saving to: ‘text.651’
#
# text.651            100%[===================>]  14.88K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:13 (931 KB/s) - ‘text.651’ saved [15241/15241]
#
# --2021-08-05 08:35:13--  https://d-nb.info/365743399/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15618 (15K) [text/plain]
# Saving to: ‘text.652’
#
# text.652            100%[===================>]  15.25K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:14 (985 KB/s) - ‘text.652’ saved [15618/15618]
#
# --2021-08-05 08:35:14--  https://d-nb.info/366656414/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 20853 (20K) [text/plain]
# Saving to: ‘text.653’
#
# text.653            100%[===================>]  20.36K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:14 (1.29 MB/s) - ‘text.653’ saved [20853/20853]
#
# --2021-08-05 08:35:14--  https://d-nb.info/365181323/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 55200 (54K) [text/plain]
# Saving to: ‘text.654’
#
# text.654            100%[===================>]  53.91K  --.-KB/s    in 0.03s
#
# 2021-08-05 08:35:14 (1.66 MB/s) - ‘text.654’ saved [55200/55200]
#
# --2021-08-05 08:35:14--  https://d-nb.info/572346743/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12410 (12K) [text/plain]
# Saving to: ‘text.655’
#
# text.655            100%[===================>]  12.12K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:15 (89.9 MB/s) - ‘text.655’ saved [12410/12410]
#
# --2021-08-05 08:35:15--  https://d-nb.info/579687260/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13465 (13K) [text/plain]
# Saving to: ‘text.656’
#
# text.656            100%[===================>]  13.15K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:15 (97.6 MB/s) - ‘text.656’ saved [13465/13465]
#
# --2021-08-05 08:35:15--  https://d-nb.info/367608790/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7817 (7.6K) [text/plain]
# Saving to: ‘text.657’
#
# text.657            100%[===================>]   7.63K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:15 (167 MB/s) - ‘text.657’ saved [7817/7817]
#
# --2021-08-05 08:35:15--  https://d-nb.info/365743275/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14458 (14K) [text/plain]
# Saving to: ‘text.658’
#
# text.658            100%[===================>]  14.12K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:16 (72.1 MB/s) - ‘text.658’ saved [14458/14458]
#
# --2021-08-05 08:35:16--  https://d-nb.info/365743321/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15810 (15K) [text/plain]
# Saving to: ‘text.659’
#
# text.659            100%[===================>]  15.44K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:16 (1007 KB/s) - ‘text.659’ saved [15810/15810]
#
# --2021-08-05 08:35:16--  https://d-nb.info/365743348/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16372 (16K) [text/plain]
# Saving to: ‘text.660’
#
# text.660            100%[===================>]  15.99K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:16 (1.00 MB/s) - ‘text.660’ saved [16372/16372]
#
# --2021-08-05 08:35:16--  https://d-nb.info/361308795/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7407 (7.2K) [text/plain]
# Saving to: ‘text.661’
#
# text.661            100%[===================>]   7.23K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:17 (152 MB/s) - ‘text.661’ saved [7407/7407]
#
# --2021-08-05 08:35:17--  https://d-nb.info/363621814/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 21452 (21K) [text/plain]
# Saving to: ‘text.662’
#
# text.662            100%[===================>]  20.95K  --.-KB/s    in 0.02s
#
# 2021-08-05 08:35:17 (1.30 MB/s) - ‘text.662’ saved [21452/21452]
#
# --2021-08-05 08:35:17--  https://d-nb.info/361208944/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2161 (2.1K) [text/plain]
# Saving to: ‘text.663’
#
# text.663            100%[===================>]   2.11K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:17 (57.0 MB/s) - ‘text.663’ saved [2161/2161]
#
# --2021-08-05 08:35:17--  https://d-nb.info/362024774/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1503 (1.5K) [text/plain]
# Saving to: ‘text.664’
#
# text.664            100%[===================>]   1.47K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:17 (124 MB/s) - ‘text.664’ saved [1503/1503]
#
# --2021-08-05 08:35:17--  https://d-nb.info/580171256/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5887 (5.7K) [text/plain]
# Saving to: ‘text.665’
#
# text.665            100%[===================>]   5.75K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:18 (129 MB/s) - ‘text.665’ saved [5887/5887]
#
# --2021-08-05 08:35:18--  https://d-nb.info/579860299/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5380 (5.3K) [text/plain]
# Saving to: ‘text.666’
#
# text.666            100%[===================>]   5.25K  --.-KB/s    in 0s
#
# 2021-08-05 08:35:18 (115 MB/s) - ‘text.666’ saved [5380/5380]
#
# FINISHED --2021-08-05 08:35:18--
# Total wall clock time: 3m 29s
# Downloaded: 748 files, 4.3M in 1.5s (2.80 MB/s)

# %% [markdown]
# Die heruntergeladenen Textdateien können jetzt nach einem Suchwort, z.B. search = "Wild" durchsucht werden. Hierbei wird die Groß- und Kleinschreibung beachtet.
# Die Treffer werden mit Angabe der Zeile und Datei ausgegeben. Dabei entspricht die Dateibenennung den im Verzeichnis heruntergeladen Textdateien (text, text1, text2 usw.).
# Das Suchwort kann beliebig geändert und durch Ausführen des Codes die Suche angepasst werden.

# %%
search = 'Handarbeit'

filename = 'text'
with open(filename) as f:
    for num, line in enumerate(f, 1):
        if search in line:
            print('%s - found at line in text:' % search, num)
        else:
            print('Kein Ergebnis vorhanden')
            
filename2 = 'text.1'
with open(filename2) as f:
    for num, line in enumerate(f, 1):
        if search in line:
            print('%s - found at line in text.1:' % search, num)
        else:
            print('Kein Ergebnis vorhanden')

# %%
#Import os module
import os

# Ask the user to enter string to search
search_path = input("Enter directory path to search : ")
file_type = input("File Type : ")
search_str = input("Enter the search string : ")

# Append a directory separator if not already present
if not (search_path.endswith("/") or search_path.endswith("\\") ): 
        search_path = search_path + "/"
                                                          
# If path does not exist, set search path to current directory
if not os.path.exists(search_path):
        search_path ="."

# Repeat for each file in the directory  
for fname in os.listdir(path=search_path):

   # Apply file type filter   
   if fname.endswith(file_type):

        # Open file for reading
        fo = open(search_path + fname)

        # Read the first line from the file
        line = fo.readline()

        # Initialize counter for line number
        line_no = 1

        # Loop until EOF
        while line != '' :
                # Search for string in line
                index = line.find(search_str)
                if ( index != -1) :
                    print(fname, "[", line_no, ",", index, "] ", line, sep="")

                # Read next line
                line = fo.readline()  

                # Increment line counter
                line_no += 1
        # Close the files
        fo.close()

# %% [markdown]
# ## Analysieren von OCR-Dateien

# %% [markdown]
# ## OCR-Datei nach Suchbegriffen durchsuchen

# %% [markdown]
# Zum Analysieren von OCR-Dateeien wird die Library "re" benötigt.

# %%
import re

# %% [markdown]
# In diesem Tutorial nutzen wir eine OCR-Datei des DNBLab. Diese wird im (Binder)Verzeichnis abgelegt. Damit die Datei durchsuchbar wird, wird der Text des Dokuments in einen String umgewandelt. Für eine bessere Durchsuchbarkeit, werden alle Zeichen des Dokuments in Kleinbuchstaben umgewandelt.

# %%
# Öffnen der Datei, 'r' regelt den Rechtezugriff
document_text = open ('102655246X_OCR.txt', 'r') 

# Umwandeln der Datei in einen String
text_string = document_text.read()

# Umwandeln der Textdatei in Kleinbuchstaben
text_string1 = text_string.lower()

# %% [markdown]
# Für die weitere Verarbeitung wird eine Liste erstelt, die die Inhalte der OCR-Datei beinhaltet.

# %%
lines = [] #Erstellt eine leere Liste
for line in text_string1.splitlines():
    lines.append(line) #befüllt die Liste mit der jeweiligen Zeile

# %% [markdown]
# Suchen wir nun einen bestimmten Begriff, so nutzen wir einen re.search-Befehl, um die Position des Wortes im Dokument zu finden.

# %%
for element in lines:
    a = re.search('file', element)
    if a: 
        print(a)

# %% [markdown]
# Alternativ kann die Search-Funktion, die bekannt aus der Analyse des Inhaltsverzeichnissen ist, genutzt werden.

# %%
search = 'krieg'

filename = '102655246X_OCR.txt'
with open(filename) as f:
    for num, line in enumerate(f, 1):
        if search in line:
            print('%s - found at line in text:' % search, num)

# %% [markdown]
# ## Häufigkeitsanalyse von regulären Ausdrucken

# %% [markdown]
# Nach dem Import der Libary re und dem Öffnen OCR-Datei sowie der Umwandlung in String und Kleinschreibung, muss im Code ein regulärer Ausdruck definiert werden.

# %%
import re 

# Öffnen der Datei, 'r' regelt den Rechtezugriff
document_text = open ('102655246X_OCR.txt', 'r') 

# Umwandeln der Datei in einen String
text_string = document_text.read()

# Umwandeln der Textdatei in Kleinbuchstaben
text_string1 = text_string.lower()

## Anmerkung, hier muss noch der Teil zu regulären Ausdrücken + Erklärungen der einzelnen Abschnitte hin 
for r in lines:
    
    a = re.match('document_text', text_string)
    
print(a)
# Out:
# None

# %% [markdown]
# ## Ausgabe der OCR

# %% [markdown]
# Zur Weiterverarbeitung ist es auch möglich, sich den Inhalt der OCR-Datei direkt im Dokument ausgeben zu lassen. Dafür genügt es den Inhalt der OCR-Datei als Liste zu definieren und sich über einen Print-Befehl ausgeben zu lassen.

# %%
##OCR-Ausgabe :D - Testen! 

document_text = open ('102655246X_OCR.txt', 'r') 
text_string = document_text.read ()
text_string = document_text.read (). lower ()

with open("102655246X_OCR.txt", "r") as tf:
    lines = tf.read().split('\n')

for r in lines:
    
    a = re.match('document_text', text_string)
    
print(lines)

# %% [markdown]
# ## Codeschnippsel für reguläre Ausdrücke beginnen hier

# %%
match_pattern = re.findall ('102655246X_OCR.txt' '\ b [a-z] 3,15  \ b ')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-3fa749034787> in <module>
# ----> 1 match_pattern = re.findall ('102655246X_OCR.txt' '\ b [a-z] 3,15  \ b ')
#       2
#
# TypeError: findall() missing 1 required positional argument: 'string'

# %%
match_pattern: count = frequency.get (word, 0) Frequenz [word] = count + 1

# %%
frequency_list = frequency.keys ()

# %%
frequency_list: Wörter drucken, Häufigkeit [Wörter]

# %%
# Out:
#   File "<ipython-input-1-df4597f046d6>", line 1
#     import re import string frequency =  document_text = open ('102655246X_OCR.txt', 'r') text_string = document_text.read (). lower () match_pattern = re.findall (r '\ b [az] 3,15  \ b ', text_string) für ein Wort in match_pattern: count = frequency.get (word, 0) frequency [word] = count + 1 frequency_list = frequency.keys () für Wörter in frequency_list: Wörter drucken, Häufigkeit [words]
#                    ^
# SyntaxError: invalid syntax

# %%
Ideen:
    Eine Suchanfrage, die alle regulären Ausdrücke findet
    Eine Suchanfrage für einen bestimmen Begriff
