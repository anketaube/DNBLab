# %% [markdown]
# # Willkommen bei EFA22@DNB!

# %% [markdown]
# Lernen wir gemeinsamen die Grundlagen der wichtigsten Funktionen von Jupyter Notebooks!

# %% [markdown]
# ## Weiteres Programm:
# Der folgende Code gibt uns die weiteren Programmpunkte aus. Lassen Sie uns auf ▸ drücken, um den Code zu starten!

# %%
print('14:15–15:00 Uhr Arbeiten mit den Daten: \nIm DNBLab stehen Coding-Tutorials bereit, die Sie auch ohne Programmierkenntnisse nutzen können. Was sind Jupyter Notebooks und wie kann ich Daten für maschinelle Abfragen und Analysen nutzen?\n\n15:00 – 15:30 Uhr: Daten visualisieren:\nWie bereitet man Daten auf und visualisiert die Ergebnisse?\n\n15:30 – 15:45 Uhr: Fragen & Feedback')
# Out:
# 14:15–15:00 Uhr Arbeiten mit den Daten:
# Im DNBLab stehen Coding-Tutorials bereit, die Sie auch ohne Programmierkenntnisse nutzen können. Was sind Jupyter Notebooks und wie kann ich Daten für maschinelle Abfragen und Analysen nutzen?
#
# 15:00 – 15:30 Uhr: Daten visualisieren:
# Wie bereitet man Daten auf und visualisiert die Ergebnisse?
#
# 15:30 – 15:45 Uhr: Fragen & Feedback

# %% [markdown]
# ## Speichern nicht vergessen!

# %% [markdown]
# Über den Download-Button in der Navigation können Ihre Ergebnisse heruntergeladen werden.

# %% [markdown]
# ## Später weiterarbeiten?
# Kein Problem. Nutzen Sie den Hochladen-Button ↥ im Launcher auf der linken Seite.

# %% [markdown]
# # Wir freuen uns über Ihre Teilnahme!

# %%
print('Weiter geht es mit den Tutorials!')
# Out:
# Weiter geht es mit den Tutorials!
