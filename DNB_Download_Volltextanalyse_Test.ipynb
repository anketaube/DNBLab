# %% [markdown]
# # DNBLab Jupyter Notebook Tutorial

# %% [markdown]
# ## Test Volltextsuche

# %% [markdown]
# Download NP

# %%
# !wget https://d-nb.info/1026552451/34
# Out:
# --2021-07-16 05:04:57--  https://d-nb.info/1026552451/34
# Resolving d-nb.info (d-nb.info)... 193.175.100.223
# Connecting to d-nb.info (d-nb.info)|193.175.100.223|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘34’
#
# 34                      [      <=>           ]   5.89M  5.38MB/s    in 1.1s
#
# 2021-07-16 05:04:59 (5.38 MB/s) - ‘34’ saved [6179255]

# %% [markdown]
# Entpacken Digitalisat

# %%
# !unzip 34
# Out:
# Archive:  34
#   inflating: 06460010.tif
#   inflating: 06610000.tif
#   inflating: 1026552451_OCR.xml
#   inflating: 1026552451_OCR.txt
#   inflating: 06510015.tif
#   inflating: 06550019.tif
#   inflating: 0636000c.tif
#   inflating: 06540018.tif
#   inflating: 06500014.tif
#   inflating: 06620000.tif
#   inflating: 06570001.tif
#   inflating: 06470011.tif
#   inflating: 06440008.tif
#   inflating: 06580002.tif
#   inflating: 06560020.tif
#   inflating: 1026552451.pdf
#   inflating: 06400004.tif
#   inflating: 06370001.tif
#   inflating: 06420006.tif
#   inflating: 06450009.tif
#   inflating: 06590003.tif
#   inflating: 06480012.tif
#   inflating: 06600004.tif
#   inflating: 06410005.tif
#   inflating: 06390003.tif
#   inflating: 06490013.tif
#   inflating: 06430007.tif
#   inflating: 1026552451_METS_old.xml
#   inflating: 06380002.tif
#   inflating: 06520016.tif
#   inflating: 1026552451.xml
#   inflating: 06530017.tif

# %% [markdown]
# Eingabe eines Suchwortes:

# %%
from IPython.display import display 
import ipywidgets as widgets 
from ipywidgets import interact, Layout 

tb1 = widgets.Text(value = 'Amerika', description='Stichwort: ');display(tb1);

# ein Button zur Übernahme der eingegebenen Werte 
button = widgets.Button(description='Übernehmen!', layout=Layout(width='200px')); 
button.style.button_color = 'lightgreen';display(button); 
def on_button_clicked(sender): 
    a = int(tb1.value)
    print('Suchhwort: ' + str(tb1.value))  
    button.on_click(on_button_clicked)
# Out:
# Text(value='Amerika', description='Stichwort: ')
# Button(description='Übernehmen!', layout=Layout(width='200px'), style=ButtonStyle(button_color='lightgreen'))

# %% [markdown]
# Einfügen der IDN_OCR.txt und ausführen der Suche mit übernommenen Suchwort:

# %%
filename = '1026552451_OCR.txt'
search = str(tb1.value)
with open(filename) as f:
    for num, line in enumerate(f, 1):
        if search in line:
            print('%s - found at line:' % search, num)
# Out:
# Amerika - found at line: 620
# Amerika - found at line: 639
# Amerika - found at line: 642
# Amerika - found at line: 1147
# Amerika - found at line: 1491
# Amerika - found at line: 1616
# Amerika - found at line: 1918
# Amerika - found at line: 2621
# Amerika - found at line: 2728

# %% [markdown]
# Download mehrere TOCs

# %%
# !wget http://d-nb.info/870073648/04/text https://d-nb.info/1218605138/04/text
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2021-07-16 05:33:42--  https://d-nb.info/870073648/04/text
# Resolving d-nb.info (d-nb.info)... 193.175.100.223
# Connecting to d-nb.info (d-nb.info)|193.175.100.223|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 643 [text/plain]
# Saving to: ‘text.1’
#
# text.1              100%[===================>]     643  --.-KB/s    in 0s
#
# 2021-07-16 05:33:42 (50.3 MB/s) - ‘text.1’ saved [643/643]
#
# --2021-07-16 05:33:42--  https://d-nb.info/1218605138/04/text
# Reusing existing connection to d-nb.info:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10441 (10K) [text/plain]
# Saving to: ‘text.2’
#
# text.2              100%[===================>]  10.20K  --.-KB/s    in 0s
#
# 2021-07-16 05:33:43 (53.1 MB/s) - ‘text.2’ saved [10441/10441]
#
# FINISHED --2021-07-16 05:33:43--
# Total wall clock time: 0.8s
# Downloaded: 2 files, 11K in 0s (52.9 MB/s)

# %% [markdown]
# Durchsuchen mehrerer TOCs im TXT-Format nach Stichwort "Inhalt"

# %%
search = 'Inhalt'

filename = 'text.1'
with open(filename) as f:
    for num, line in enumerate(f, 1):
        if search in line:
            print('%s - found at line in filename1:' % search, num)
filename2 = 'text.2'
with open(filename2) as f:
    for num, line in enumerate(f, 1):
        if search in line:
            print('%s - found at line in filename2:' % search, num)
# Out:
# Inhalt - found at line in filename1: 1
# Inhalt - found at line in filename2: 1
